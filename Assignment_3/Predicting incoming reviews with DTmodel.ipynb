# %%
import threading

# Helper thread to avoid the Spark StreamingContext from blocking Jupyter
        
class StreamingThread(threading.Thread):
    def __init__(self, ssc):
        super().__init__()
        self.ssc = ssc
    def run(self):
        self.ssc.start()
        self.ssc.awaitTermination()
    def stop(self):
        print('----- Stopping... this may take a few seconds -----')
        self.ssc.stop(stopSparkContext=False, stopGraceFully=True)

# %%
sc
# Out:
# <SparkContext master=local[*] appName=PySparkShell>

# %%
spark
# Out:
#             <div>
#                 <p><b>SparkSession - hive</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://DESKTOP-VJVJ8QV:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.3.2</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>PySparkShell</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
from pyspark.streaming import StreamingContext
from pyspark.ml import PipelineModel

# %%
globals()['models_loaded'] = False
globals()['my_model'] = None

def process(time, rdd):
    if rdd.isEmpty():
        return
    
    print("========= %s =========" % str(time))
    
    # Convert to data frame
    df = spark.read.json(rdd)
    df.show()

     # Load in the model if not yet loaded:
    if not globals()['models_loaded']:
        # load in your models here
        globals()['my_model'] = PipelineModel.load('DTmodel') 
        globals()['models_loaded'] = True
        
    # And then predict using the loaded model (uncomment below):
    
    df_result = globals()['my_model'].transform(df)
    df_result.show()

# %%
ssc = StreamingContext(sc, 10)

# %%
lines = ssc.socketTextStream("seppe.net", 7778)
lines.foreachRDD(process)

# %%
ssc_t = StreamingThread(ssc)
ssc_t.start()
# Out:
# +-------+-----+---------+--------------------+--------------------+--------------------+--------------------+----------------+--------------------+----------+
# | app_id|label|review_id|         review_text|              tokens|     filtered_tokens|            features|   rawPrediction|         probability|prediction|
# +-------+-----+---------+--------------------+--------------------+--------------------+--------------------+----------------+--------------------+----------+
# |2008100|    1|139151055|                 yes|               [yes]|               [yes]|(127099,[456],[1.0])|[8900.0,58338.0]|[0.13236562658020...|       1.0|
# |1304930|    1|139153587|                good|              [good]|              [good]|  (127099,[6],[1.0])|[8900.0,58338.0]|[0.13236562658020...|       1.0|
# |1304930|    1|139153195|This game is awes...|[this, game, is, ...|[game, awesome, t...|(127099,[0,19,25,...|[8900.0,58338.0]|[0.13236562658020...|       1.0|
# +-------+-----+---------+--------------------+--------------------+--------------------+--------------------+----------------+--------------------+----------+
#
# ========= 2023-05-28 17:19:50 =========
# +-------+-----+---------+--------------------+
# | app_id|label|review_id|         review_text|
# +-------+-----+---------+--------------------+
# |1304930|    1|139153188|me like funny sca...|
# |1304930|    1|139153178|I love this!!!!! ...|
# |1304930|    0|139152036|Dumb “game as a s...|
# +-------+-----+---------+--------------------+
#
# +-------+-----+---------+--------------------+--------------------+--------------------+--------------------+----------------+--------------------+----------+
# | app_id|label|review_id|         review_text|              tokens|     filtered_tokens|            features|   rawPrediction|         probability|prediction|
# +-------+-----+---------+--------------------+--------------------+--------------------+--------------------+----------------+--------------------+----------+
# |1304930|    1|139153188|me like funny sca...|[me, like, funny,...|[like, funny, sca...|(127099,[0,2,210,...|[8900.0,58338.0]|[0.13236562658020...|       1.0|
# |1304930|    1|139153178|I love this!!!!! ...|[i, love, this!!!...|[love, this!!!!!,...|(127099,[15,22,42...|[8900.0,58338.0]|[0.13236562658020...|       1.0|
# |1304930|    0|139152036|Dumb “game as a s...|[dumb, “game, as,...|[dumb, “game, ser...|(127099,[1576,354...|[8900.0,58338.0]|[0.13236562658020...|       1.0|
# +-------+-----+---------+--------------------+--------------------+--------------------+--------------------+----------------+--------------------+----------+
#
# ========= 2023-05-28 17:20:00 =========
# +-------+-----+---------+--------------------+
# | app_id|label|review_id|         review_text|
# +-------+-----+---------+--------------------+
# |1304930|    1|139151782|The Outlast Multi...|
# |1304930|    1|139151444|"If You Ain't Gui...|
# |1304930|    1|139151268|The game is not t...|
# +-------+-----+---------+--------------------+
#
# +-------+-----+---------+--------------------+--------------------+--------------------+--------------------+----------------+--------------------+----------+
# | app_id|label|review_id|         review_text|              tokens|     filtered_tokens|            features|   rawPrediction|         probability|prediction|
# +-------+-----+---------+--------------------+--------------------+--------------------+--------------------+----------------+--------------------+----------+
# |1304930|    1|139151782|The Outlast Multi...|[the, outlast, mu...|[outlast, multipl...|(127099,[5,7,23,4...|[8900.0,58338.0]|[0.13236562658020...|       1.0|
# |1304930|    1|139151444|"If You Ain't Gui...|["if, you, ain't,...|["if, ain't, guil...|(127099,[4063],[1...|[8900.0,58338.0]|[0.13236562658020...|       1.0|
# |1304930|    1|139151268|The game is not t...|[the, game, is, n...|[game, scary, mul...|(127099,[0,2,26,4...|[8900.0,58338.0]|[0.13236562658020...|       1.0|
# +-------+-----+---------+--------------------+--------------------+--------------------+--------------------+----------------+--------------------+----------+
#
# ========= 2023-05-28 17:20:30 =========
# +-------+-----+---------+--------------------+
# | app_id|label|review_id|         review_text|
# +-------+-----+---------+--------------------+
# | 754890|    0|139150846|I can't see what ...|
# |2348650|    1|139152401|            its cute|
# |1871770|    1|139151372|Fun game but stil...|
# |1062810|    1|139152997|Fun for your mone...|
# +-------+-----+---------+--------------------+
#
# +-------+-----+---------+--------------------+--------------------+--------------------+--------------------+----------------+--------------------+----------+
# | app_id|label|review_id|         review_text|              tokens|     filtered_tokens|            features|   rawPrediction|         probability|prediction|
# +-------+-----+---------+--------------------+--------------------+--------------------+--------------------+----------------+--------------------+----------+
# | 754890|    0|139150846|I can't see what ...|[i, can't, see, w...|[see, accomplishi...|(127099,[8,9,11,5...|[8900.0,58338.0]|[0.13236562658020...|       1.0|
# |2348650|    1|139152401|            its cute|         [its, cute]|              [cute]|(127099,[1702],[1...|[8900.0,58338.0]|[0.13236562658020...|       1.0|
# |1871770|    1|139151372|Fun game but stil...|[fun, game, but, ...|[fun, game, still...|(127099,[0,1,5,8,...|[8900.0,58338.0]|[0.13236562658020...|       1.0|
# |1062810|    1|139152997|Fun for your mone...|[fun, for, your, ...|[fun, money., abs...|(127099,[0,1,3,4,...|  [237.0,9489.0]|[0.02436767427513...|       1.0|
# +-------+-----+---------+--------------------+--------------------+--------------------+--------------------+----------------+--------------------+----------+
#
# ========= 2023-05-28 17:20:40 =========
# +-------+-----+---------+--------------------+
# | app_id|label|review_id|         review_text|
# +-------+-----+---------+--------------------+
# |2141910|    0|139153316|I hate this game ...|
# |2141910|    0|139153213|It feels like Wiz...|
# |2141910|    1|139152451|I can't even smel...|
# +-------+-----+---------+--------------------+
#
# +-------+-----+---------+--------------------+--------------------+--------------------+--------------------+----------------+--------------------+----------+
# | app_id|label|review_id|         review_text|              tokens|     filtered_tokens|            features|   rawPrediction|         probability|prediction|
# +-------+-----+---------+--------------------+--------------------+--------------------+--------------------+----------------+--------------------+----------+
# |2141910|    0|139153316|I hate this game ...|[i, hate, this, g...|[hate, game, keep...|(127099,[0,18,23,...|[8900.0,58338.0]|[0.13236562658020...|       1.0|
# |2141910|    0|139153213|It feels like Wiz...|[it, feels, like,...|[feels, like, wiz...|(127099,[0,1,2,3,...|[8900.0,58338.0]|[0.13236562658020...|       1.0|
# |2141910|    1|139152451|I can't even smel...|[i, can't, even, ...|[even, smell, opp...|(127099,[12,9691]...|[8900.0,58338.0]|[0.13236562658020...|       1.0|
# +-------+-----+---------+--------------------+--------------------+--------------------+--------------------+----------------+--------------------+----------+
#
# ========= 2023-05-28 17:20:50 =========
# +-------+-----+---------+--------------------+
# | app_id|label|review_id|         review_text|
# +-------+-----+---------+--------------------+
# |1649010|    1|139153035|recommended with ...|
# |1649010|    0|139151704|Yey again, in 202...|
# |1607680|    1|139149904|Just paid $20 for...|
# +-------+-----+---------+--------------------+
#
# +-------+-----+---------+--------------------+--------------------+--------------------+--------------------+----------------+--------------------+----------+
# | app_id|label|review_id|         review_text|              tokens|     filtered_tokens|            features|   rawPrediction|         probability|prediction|
# +-------+-----+---------+--------------------+--------------------+--------------------+--------------------+----------------+--------------------+----------+
# |1649010|    1|139153035|recommended with ...|[recommended, wit...|[recommended, cav...|(127099,[0,1,2,7,...|[8900.0,58338.0]|[0.13236562658020...|       1.0|
# |1649010|    0|139151704|Yey again, in 202...|[yey, again,, in,...|[yey, again,, 202...|(127099,[1,2,4,18...|[8900.0,58338.0]|[0.13236562658020...|       1.0|
# |1607680|    1|139149904|Just paid $20 for...|[just, paid, $20,...|[paid, $20, rage,...|(127099,[0,1,20,3...|[8900.0,58338.0]|[0.13236562658020...|       1.0|
# +-------+-----+---------+--------------------+--------------------+--------------------+--------------------+----------------+--------------------+----------+
# ========= 2023-05-28 17:21:20 =========
# +-------+-----+---------+--------------------+
# | app_id|label|review_id|         review_text|
# +-------+-----+---------+--------------------+
# |2005010|    1|139153388|Nails the boomer ...|
# |2005010|    1|139152729|rip, tear...for t...|
# |2005010|    1|139152493|So as a disclaime...|
# +-------+-----+---------+--------------------+
#
# +-------+-----+---------+--------------------+--------------------+--------------------+--------------------+----------------+--------------------+----------+
# | app_id|label|review_id|         review_text|              tokens|     filtered_tokens|            features|   rawPrediction|         probability|prediction|
# +-------+-----+---------+--------------------+--------------------+--------------------+--------------------+----------------+--------------------+----------+
# |2005010|    1|139153388|Nails the boomer ...|[nails, the, boom...|[nails, boomer, s...|(127099,[1,2,5,13...|[8900.0,58338.0]|[0.13236562658020...|       1.0|
# |2005010|    1|139152729|rip, tear...for t...|[rip,, tear...for...|[rip,, tear...for...|(127099,[23831,31...|[8900.0,58338.0]|[0.13236562658020...|       1.0|
# |2005010|    1|139152493|So as a disclaime...|[so, as, a, discl...|[disclaimer,, ret...|(127099,[1,2,4,13...|[8900.0,58338.0]|[0.13236562658020...|       1.0|
# +-------+-----+---------+--------------------+--------------------+--------------------+--------------------+----------------+--------------------+----------+
#
# ========= 2023-05-28 17:21:30 =========
# +-------+-----+---------+--------------------+
# | app_id|label|review_id|         review_text|
# +-------+-----+---------+--------------------+
# |2005010|    0|139152390|Good game with qu...|
# |2005010|    1|139152268|If you like 40k A...|
# |2005010|    1|139151903|This game rocks. ...|
# +-------+-----+---------+--------------------+
#
# +-------+-----+---------+--------------------+--------------------+--------------------+--------------------+----------------+--------------------+----------+
# | app_id|label|review_id|         review_text|              tokens|     filtered_tokens|            features|   rawPrediction|         probability|prediction|
# +-------+-----+---------+--------------------+--------------------+--------------------+--------------------+----------------+--------------------+----------+
# |2005010|    0|139152390|Good game with qu...|[good, game, with...|[good, game, ques...|(127099,[0,1,2,4,...|[8900.0,58338.0]|[0.13236562658020...|       1.0|
# |2005010|    1|139152268|If you like 40k A...|[if, you, like, 4...|[like, 40k, boome...|(127099,[0,1,2,3,...|[8900.0,58338.0]|[0.13236562658020...|       1.0|
# |2005010|    1|139151903|This game rocks. ...|[this, game, rock...|[game, rocks., pl...|(127099,[0,2,5,7,...|[8900.0,58338.0]|[0.13236562658020...|       1.0|
# +-------+-----+---------+--------------------+--------------------+--------------------+--------------------+----------------+--------------------+----------+
#
# ========= 2023-05-28 17:21:40 =========
# +-------+-----+---------+--------------------+
# | app_id|label|review_id|         review_text|
# +-------+-----+---------+--------------------+
# |2005010|    1|139151841|I can't even say ...|
# |2005010|    1|139151768|            Fun game|
# |2005010|    1|139151627|DO NOT RECOMMEND!...|
# |2005010|    1|139151090|DOOM but 40k is s...|
# +-------+-----+---------+--------------------+
#
# +-------+-----+---------+--------------------+--------------------+--------------------+--------------------+----------------+--------------------+----------+
# | app_id|label|review_id|         review_text|              tokens|     filtered_tokens|            features|   rawPrediction|         probability|prediction|
# +-------+-----+---------+--------------------+--------------------+--------------------+--------------------+----------------+--------------------+----------+
# |2005010|    1|139151841|I can't even say ...|[i, can't, even, ...|[even, say, "they...|(127099,[1,2,4,12...|[8900.0,58338.0]|[0.13236562658020...|       1.0|
# |2005010|    1|139151768|            Fun game|         [fun, game]|         [fun, game]|(127099,[0,5],[1....|[8900.0,58338.0]|[0.13236562658020...|       1.0|
# |2005010|    1|139151627|DO NOT RECOMMEND!...|[do, not, recomme...|[recommend!, , ye...|(127099,[0,1,4,5,...|[8900.0,58338.0]|[0.13236562658020...|       1.0|
# |2005010|    1|139151090|DOOM but 40k is s...|[doom, but, 40k, ...|[doom, 40k, somet...|(127099,[37,103,2...|[8900.0,58338.0]|[0.13236562658020...|       1.0|
# +-------+-----+---------+--------------------+--------------------+--------------------+--------------------+----------------+--------------------+----------+

# %%
ssc_t.stop()
# Out:
# ========= 2023-05-28 17:22:10 =========
# ----- Stopping... this may take a few seconds -----
# +-------+-----+---------+--------------------+
# | app_id|label|review_id|         review_text|
# +-------+-----+---------+--------------------+
# |2218750|    0|139153211|am i forced to eq...|
# |2218750|    1|139152148|Fun and Addicting...|
# |2218750|    1|139152080|Diablo 1 + Vampir...|
# |2218750|    1|139152065|Must... kill........|
# |2218750|    1|139151602|Vampire Survivors...|
# +-------+-----+---------+--------------------+
#
# +-------+-----+---------+--------------------+--------------------+--------------------+--------------------+----------------+--------------------+----------+
# | app_id|label|review_id|         review_text|              tokens|     filtered_tokens|            features|   rawPrediction|         probability|prediction|
# +-------+-----+---------+--------------------+--------------------+--------------------+--------------------+----------------+--------------------+----------+
# |2218750|    0|139153211|am i forced to eq...|[am, i, forced, t...|[forced, equip, r...|(127099,[0,66,175...|[8900.0,58338.0]|[0.13236562658020...|       1.0|
# |2218750|    1|139152148|Fun and Addicting...|[fun, and, addict...|[fun, addicting!,...|(127099,[5,304,77...|[8900.0,58338.0]|[0.13236562658020...|       1.0|
# |2218750|    1|139152080|Diablo 1 + Vampir...|[diablo, 1, +, va...|[diablo, 1, +, va...|(127099,[1,3,6,7,...|  [237.0,9489.0]|[0.02436767427513...|       1.0|
# |2218750|    1|139152065|Must... kill........|[must..., kill......|[must..., kill......|(127099,[1,22,300...|[8900.0,58338.0]|[0.13236562658020...|       1.0|
# |2218750|    1|139151602|Vampire Survivors...|[vampire, survivo...|[vampire, survivo...|(127099,[557,4590...|[8900.0,58338.0]|[0.13236562658020...|       1.0|
# +-------+-----+---------+--------------------+--------------------+--------------------+--------------------+----------------+--------------------+----------+
